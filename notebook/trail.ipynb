# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"D:\LNBTI lecture materials\7th Semester\Final Project\Electricity_Prediction_Project\notebook\electricity_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2401 entries, 0 to 2400
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   household_id             2401 non-null   int64
#  1   date                     2401 non-null   object
#  2   location_type            2401 non-null   object
#  3   climate_zone             2401 non-null   object
#  4   household_size           2401 non-null   int64
#  5   income_level             2401 non-null   object
#  6   inflation_rate           2401 non-null   float64
#  7   electricity_tariff_rate  2401 non-null   float64
#  8   past_month_units         2401 non-null   float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 168.9+ KB
